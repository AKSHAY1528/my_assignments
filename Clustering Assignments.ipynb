# %% [markdown]
# # Airlines data

# %% [markdown]
# ## Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Read the dataset

# %%
df=pd.read_excel("EastWestAirlines.xlsx",sheet_name='data')

# %%
df
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
df=df.drop('ID#',axis=1)

# %%
def norm_func(i):
    x = (i-i.min())/(i.max()-i.min()) 
    return (x)

# %%
#normalization for exrtracting the numereic values
df_norm = norm_func(df.iloc[:,1:])
df_norm
# Out:
#       Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  Bonus_trans  \
# 0            0.0       0.00        0.0        0.0     0.000660     0.011628
# 1            0.0       0.00        0.0        0.0     0.000815     0.023256
# 2            0.0       0.00        0.0        0.0     0.015636     0.046512
# 3            0.0       0.00        0.0        0.0     0.001896     0.011628
# 4            0.0       0.75        0.0        0.0     0.164211     0.302326
# ...          ...        ...        ...        ...          ...          ...
# 3994         0.0       0.00        0.0        0.0     0.032330     0.046512
# 3995         0.0       0.00        0.0        0.0     0.003720     0.058140
# 3996         0.0       0.50        0.0        0.0     0.096505     0.093023
# 3997         0.0       0.00        0.0        0.0     0.001896     0.011628
# 3998         0.0       0.00        0.0        0.0     0.000000     0.000000
#
# ...

# %%
# !pip install scipy

# %%
df.corr()
# Out:
#                     Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# Balance            1.000000    0.108722   0.338344  -0.008804   0.035243
# Qual_miles         0.108722    1.000000   0.007931  -0.013923  -0.007779
# cc1_miles          0.338344    0.007931   1.000000  -0.068223   0.060555
# cc2_miles         -0.008804   -0.013923  -0.068223   1.000000  -0.006166
# cc3_miles          0.035243   -0.007779   0.060555  -0.006166   1.000000
# Bonus_miles        0.403487    0.031021   0.825200  -0.003969   0.204134
# Bonus_trans        0.324935    0.050725   0.608943   0.064399   0.097313
# Flight_miles_12mo  0.217551    0.126774   0.037370   0.010598  -0.001777
# Flight_trans_12    0.255700    0.144004   0.041333   0.028284  -0.001117
# Days_since_enroll  0.263129    0.017312   0.230849  -0.005807   0.010832
# Award?             0.178494    0.095256   0.335457   0.005332   0.023484
#
#                    Bonus_miles  Bonus_trans  Flight_miles_12mo  \
# ...

# %%
import scipy.cluster.hierarchy as sh
from sklearn.cluster import AgglomerativeClustering

# %%
# Constructing Dendogram
dendogram=sh.dendrogram(sh.linkage(df_norm,method='single'))

# %%
dendrogram = sh.dendrogram(sh.linkage(df_norm,metric='cosine',method='complete'))

# %%
hc = AgglomerativeClustering(n_clusters=4, affinity = 'euclidean', linkage = 'single')

# %%
y_hc = hc.fit_predict(df_norm)
y_hc
# Out:
# array([0, 0, 0, ..., 1, 0, 0], dtype=int64)

# %%
Clusters=pd.DataFrame(y_hc,columns=['Clusters'])
Clusters
# Out:
#       Clusters
# 0            0
# 1            0
# 2            0
# 3            0
# 4            1
# ...        ...
# 3994         1
# 3995         1
# 3996         1
# 3997         0
# 3998         0
#
# [3999 rows x 1 columns]

# %%
df["Clusters"]=Clusters

# %%
df
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
df[df['Clusters']==0]
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 5       16420           0          1          1          1            0
# ...       ...         ...        ...        ...        ...          ...
# 3991    39142           0          3          1          1        14981
# 3992    11181           0          1          1          1          929
# 3993     3974           0          1          1          1          365
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
df[df['Clusters']==1]
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 4       97752           0          4          1          1        43300
# 7       20856           0          1          1          1         5250
# 8      443003           0          3          2          1         1753
# 9      104860           0          3          1          1        28426
# 11      96522           0          5          1          1        61105
# ...       ...         ...        ...        ...        ...          ...
# 3987    11933           0          1          1          1          249
# 3989     2622           0          1          1          1         1625
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
df[df['Clusters']==2]
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 3583   160114         500          1          1          1        71954
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 3583           86              30817               53               1373
#
#       Award?  Clusters  new_clustres  DBSCANS
# 3583       1         2             0       -1

# %%
df[df['Clusters']==3]
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 2840     8557           0          1          1          1       200622
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 2840            5                622                3               1955
#
#       Award?  Clusters  new_clustres  DBSCANS
# 2840       1         3             3       -1

# %% [markdown]
# # Applying K-means

# %%
from sklearn.cluster import KMeans

# %%
df_k=pd.read_excel("EastWestAirlines.xlsx",sheet_name='data')

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
scaled_data=sc.fit_transform(df_k)

# %%
kmeans=KMeans(n_clusters=4,random_state=5)

# %%
kmeans.fit(scaled_data)
# Out:
# KMeans(n_clusters=4, random_state=5)

# %%
df_k["Clusters"]=kmeans.predict(scaled_data)

# %%
df_k["Clusters"]
# Out:
# 0       2
# 1       2
# 2       2
# 3       2
# 4       3
#        ..
# 3994    0
# 3995    0
# 3996    0
# 3997    0
# 3998    0
# Name: Clusters, Length: 3999, dtype: int32

# %%
df_k
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
wcss = []
for i in range(1,12):
    kmeans = KMeans(n_clusters=i,random_state=0)
    kmeans.fit(scaled_data)
    dist = kmeans.inertia_
    wcss.append(dist)

# %%
wcss
# Out:
# [47988.00000000001,
#  39018.84742954433,
#  34529.168666113335,
#  30616.62363609265,
#  26894.75305989324,
#  23490.74902876985,
#  21885.3682448693,
#  19330.695176303714,
#  18015.300658980443,
#  16846.161847375988,
#  15774.923677280553]

# %%
plt.plot(range(1,12),wcss)
plt.title("Elbow Method")
plt.xlabel("Number of cluster")
plt.ylabel("Within a cluster sum of square")
plt.grid()

# %%
from sklearn.cluster import KMeans
clusters_new = KMeans(6, random_state=0)
clusters_new.fit(scaled_data)
# Out:
# KMeans(n_clusters=6, random_state=0)

# %%
df['new_clustres']=clusters_new.labels_

# %%
df['new_clustres']
# Out:
# 0       2
# 1       2
# 2       2
# 3       2
# 4       3
#        ..
# 3994    1
# 3995    1
# 3996    1
# 3997    1
# 3998    1
# Name: new_clustres, Length: 3999, dtype: int32

# %%
clusters_new.cluster_centers_
# Out:
# array([[-0.23852715,  1.18446344,  0.88037642,  0.11446574, -0.09824189,
#         -0.06276658,  0.63780138,  1.65423176,  3.64043543,  3.92064625,
#          0.275472  ,  0.9224481 ],
#        [ 0.96803202, -0.33839012, -0.05974896, -0.50115538, -0.09824189,
#         -0.06276658, -0.46151109, -0.41763139, -0.18820091, -0.207612  ,
#         -0.95928629, -0.35719626],
#        [-0.792215  , -0.16310888, -0.05017319, -0.50959763, -0.09824189,
#         -0.05874576, -0.47211132, -0.39177122, -0.16556507, -0.17590564,
#          0.7709545 , -0.25164813],
#        [-0.39326741,  0.51242422,  0.02653687,  1.35981814, -0.09824189,
#         -0.05276166,  1.12237626,  0.79890128, -0.06452417, -0.07095245,
#          0.39623627,  0.68913829],
#        [-0.30152248,  0.63971926, -0.08443292,  1.0220844 , -0.09824189,
#         15.64629931,  3.17969131,  1.71461374,  0.03329269,  0.05969539,
#          0.23987261,  0.33752735],
# ...

# %%
df.groupby('new_clustres').agg(['mean']).reset_index()
# Out:
#   new_clustres        Balance  Qual_miles cc1_miles cc2_miles cc3_miles  \
#                          mean        mean      mean      mean      mean
# 0            0  192951.493421  825.144737  2.217105  1.000000  1.000000
# 1            1   39504.102616   97.894702  1.369551  1.000000  1.000000
# 2            2   57165.977237  105.302198  1.357928  1.000000  1.000785
# 3            3  125234.761719  164.642578  3.931641  1.000000  1.001953
# 4            4  138061.400000   78.800000  3.466667  1.000000  4.066667
# 5            5   68876.581395   23.255814  1.139535  2.348837  1.000000
#
#     Bonus_miles Bonus_trans Flight_miles_12mo Flight_trans_12  \
#            mean        mean              mean            mean
# 0  32546.440789   27.486842       5556.789474       16.243421
# 1   6000.300469    7.591549        196.568075        0.586184
# 2   5744.326531    7.839874        228.259027        0.706436
# 3  44247.929688   19.273438        369.719727        1.104492
# ...

# %% [markdown]
# # ===============================================================

# %% [markdown]
# # DBSCAN

# %%
from sklearn.cluster import DBSCAN

# %%
Db_model=DBSCAN(eps=3,min_samples=6)

# %%
Db_model.fit(scaled_data)
# Out:
# DBSCAN(eps=3, min_samples=6)

# %%
df['DBSCANS']=Db_model.labels_

# %%
df
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
pd.value_counts(Db_model.labels_)
# Out:
#  0    3882
# -1      75
#  2      25
#  1      13
#  3       4
# dtype: int64

# %%
df[df['DBSCANS']==0]
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
df[df['DBSCANS']==1]
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 198      8669           0          1          3          1        11397
# 381    167670           0          1          3          1        15907
# 940     44824           0          1          3          1        21107
# 1270    16103           0          1          3          1        10819
# 1791    32510           0          1          3          1        14568
# 1918    52139           0          1          3          1        16314
# 2047     4148           0          1          3          1        13504
# 2278    30171           0          1          3          1        15370
# 2978    22805           0          1          3          1        26334
# 3203    64924           0          1          3          1        14971
# 3367    23197           0          1          3          1        10587
# 3611    37300           0          1          3          1        23760
# ...

# %%
df[df['DBSCANS']==-1]
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 8      443003           0          3          2          1         1753
# 65      53914           0          3          1          1        33767
# 106     96627        1182          1          1          3        49059
# 126    602064           0          5          1          1       194753
# 135    259484        1776          1          1          1        19172
# ...       ...         ...        ...        ...        ...          ...
# 3594    27619           0          4          1          1        83726
# 3772   822321           0          5          1          1       138334
# 3788   374613           0          1          2          1        23592
# 3846    97510        1678          5          1          1        71609
# 3883   126167           0          5          1          1       190160
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
df[df['DBSCANS']==2]
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 226    117329           0          1          2          1         6448
# 392     11189           0          1          2          1         9044
# 794     55610           0          1          2          1         5095
# 1149    84856           0          1          2          1         6894
# 1383    18154           0          1          2          1         7748
# 1389    49145           0          1          2          1        12755
# 1527    23965           0          1          2          1         7308
# 1541    36887           0          1          2          1         9048
# 1976    11961           0          1          2          1        11961
# 2006   101901           0          1          2          1        17898
# 2317    10458           0          1          2          1        10458
# 2421    41062           0          1          2          1         8275
# ...

# %%
df.groupby("DBSCANS").agg(['mean']).reset_index()
# Out:
#   DBSCANS        Balance   Qual_miles cc1_miles cc2_miles cc3_miles  \
#                     mean         mean      mean      mean      mean
# 0      -1  302361.240000  1540.000000  2.973333  1.093333  1.653333
# 1       0   69402.873261   110.375837  2.049974  1.000000  1.000000
# 2       1   41562.307692     0.000000  1.000000  3.000000  1.000000
# 3       2   39187.040000     0.000000  1.120000  2.000000  1.000000
# 4       3  178169.000000  8083.750000  3.500000  1.000000  1.000000
#
#     Bonus_miles Bonus_trans Flight_miles_12mo Flight_trans_12  \
#            mean        mean              mean            mean
# 0  70603.226667   30.253333       4686.960000       13.066667
# 1  16138.731839   11.197321        380.329985        1.152756
# 2  16338.230769   16.076923        323.076923        0.923077
# 3  11107.040000   14.840000        224.000000        0.800000
# 4  31592.000000   19.750000        500.000000        1.500000
#
# ...
